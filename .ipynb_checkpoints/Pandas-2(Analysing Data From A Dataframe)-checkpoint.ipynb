# %%
import pandas as pd

# %%
covid_df = pd.read_csv("./data/italy-covid-daywise.csv")

# %%
covid_df.head()
# Out:
#          date  new_cases  new_deaths  new_tests
# 0  2019-12-31        0.0         0.0        NaN
# 1  2020-01-01        0.0         0.0        NaN
# 2  2020-01-02        0.0         0.0        NaN
# 3  2020-01-03        0.0         0.0        NaN
# 4  2020-01-04        0.0         0.0        NaN

# %%
total_deaths = covid_df['new_deaths'].sum()

# %%
print("Total Death Cases in Italy are: ",total_deaths)
# Out:
# Total Death Cases in Italy are:  35497.0

# %%
death_rate = covid_df['new_deaths'].sum()/covid_df['new_cases'].sum()
print(f"The Death Rate is: {(death_rate*100):.2f}%.")
# Out:
# The Death Rate is: 13.07%.
